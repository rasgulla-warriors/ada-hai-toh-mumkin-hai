# %%
import pandas as pd
import os

l = [i for i in os.listdir(".") if i.endswith(".csv")]
df = pd.concat([pd.read_csv(i) for i in l])
df
# Out:
#        idx         PC Name    No Type                         State  \
# 0      1.0        Adilabad   1.0   ST                     Telangana
# 1      2.0            Agra  18.0   SC  Uttar Pradesh [2000 Onwards]
# 2      3.0      Ahmadnagar  37.0  GEN                   Maharashtra
# 3      4.0  Ahmedabad East   7.0  GEN                       Gujarat
# 4      5.0  Ahmedabad West   8.0   SC                       Gujarat
# ..     ...             ...   ...  ...                           ...
# 538  539.0       Vishnupur  36.0  GEN                   West Bengal
# 539  540.0        Warangal  39.0  GEN                Andhra Pradesh
# 540  541.0          Wardha  27.0  GEN                   Maharashtra
# 541  542.0          Washim  20.0   ST                   Maharashtra
# 542  543.0        Yavatmal  28.0  GEN                   Maharashtra
#
#                           Winning Candidate  \
# 0                              Godam Nagesh
# 1                  Dr. Ram Shankar Katheria
# 2              Gandhi Dilipkumar Mansukhlal
# 3                              Paresh Rawal
# 4                       Dr. Kirit P Solanki
# ..                                      ...
# 538                           Susmita Bauri
# 539                Dharavath  Ravinder Naik
# 540                  Wagmare Suresh Ganapat
# 541  Gawali (PATIL) KU.  BHAVANA PUNDLIKRAO
# 542                  Rathod Harising Nasaru
#
#                                   Party   Electors     Votes Turnout  ...  \
# 0             Telangana Rashtra Samithi    1386233   1045839  75.4 %  ...
# 1                 Bharatiya Janta Party    1814739   1070400  59.0 %  ...
# 2                 Bharatiya Janta Party    1699408   1062318  62.5 %  ...
# 3                 Bharatiya Janta Party    1601832    985525  61.5 %  ...
# 4                 Bharatiya Janta Party    1534400    964609  62.9 %  ...
# ..                                  ...        ...       ...     ...  ...
# 538  Communist Party Of India (MARXIST)  10,52,852  8,03,360  76.3 %  ...
# 539           Telangana Rashtra Samithi  12,15,167  9,21,516  75.8 %  ...
# 540               Bharatiya Janta Party  11,44,924  6,25,840  54.7 %  ...
# 541                           Shiv Sena  11,51,886  7,19,643  62.5 %  ...
# 542               Bharatiya Janta Party  11,33,605  6,63,001  58.5 %  ...
#
#     No_2024 Type_2024 State_2024  Winning Candidate_2024  Party_2024  \
# 0       NaN       NaN        NaN                     NaN         NaN
# 1       NaN       NaN        NaN                     NaN         NaN
# 2       NaN       NaN        NaN                     NaN         NaN
# 3       NaN       NaN        NaN                     NaN         NaN
# 4       NaN       NaN        NaN                     NaN         NaN
# ..      ...       ...        ...                     ...         ...
# 538     NaN       NaN        NaN                     NaN         NaN
# 539     NaN       NaN        NaN                     NaN         NaN
# 540     NaN       NaN        NaN                     NaN         NaN
# 541     NaN       NaN        NaN                     NaN         NaN
# 542     NaN       NaN        NaN                     NaN         NaN
#
#     Electors_2024 Votes_2024 Turnout_2024 Margin_2024  Margin %_2024
# 0             NaN        NaN          NaN         NaN            NaN
# 1             NaN        NaN          NaN         NaN            NaN
# 2             NaN        NaN          NaN         NaN            NaN
# 3             NaN        NaN          NaN         NaN            NaN
# 4             NaN        NaN          NaN         NaN            NaN
# ..            ...        ...          ...         ...            ...
# 538           NaN        NaN          NaN         NaN            NaN
# 539           NaN        NaN          NaN         NaN            NaN
# 540           NaN        NaN          NaN         NaN            NaN
# 541           NaN        NaN          NaN         NaN            NaN
# 542           NaN        NaN          NaN         NaN            NaN
#
# [3475 rows x 68 columns]

# %%
df.index = range(len(df))

# %%
for i in l:
    s = pd.read_csv(i)
    print(len(s), i)
# Out:
# 543 2014.csv
# 381 all.csv
# 543 2009.csv
# 543 2024.csv
# 381 cleaned.csv
# 541 2019.csv
# 543 2004.csv

# %%
import pandas as pd

df1 = pd.read_csv("2004.csv", index_col="PC Name")
df2 = pd.read_csv("2009.csv", index_col="PC Name")
df3 = pd.read_csv("2014.csv", index_col="PC Name")
df4 = pd.read_csv("2019.csv", index_col="PC Name")
df5 = pd.read_csv("2024.csv", index_col="PC Name")

df1 = df1.join(df2, how="outer", rsuffix="_2009", lsuffix="_2004")
df1 = df1.join(df3, how="outer", rsuffix="_2014")
df1 = df1.join(df4, how="outer", rsuffix="_2019")
df1 = df1.join(df5, how="outer", rsuffix="_2024")
df1.to_csv("all.csv")

# %%
df = pd.read_csv("all.csv", index_col="PC Name")
df
# Out:
#                  idx_2004  No_2004 Type_2004                    State_2004  \
# PC Name
# Adilabad              1.0     35.0       GEN                Andhra Pradesh
# Adoor                 2.0     17.0       GEN                        Kerala
# Agra                  3.0     69.0       GEN  Uttar Pradesh [2000 Onwards]
# Ahmadnagar            NaN      NaN       NaN                           NaN
# Ahmedabad             4.0     10.0       GEN                       Gujarat
# ...                   ...      ...       ...                           ...
# West Delhi            NaN      NaN       NaN                           NaN
# Yavatmal            543.0     28.0       GEN                   Maharashtra
# Yavatmal-Washi        NaN      NaN       NaN                           NaN
# Yavatmal-Washim       NaN      NaN       NaN                           NaN
# Zahirabad             NaN      NaN       NaN                           NaN
#
#                     Winning Candidate_2004                 Party_2004  \
# PC Name
# Adilabad         Madhusudhan Reddy Takkala  Telangana Rashtra Samithi
# Adoor                   Chengara Surendran   Communist Party Of India
# Agra                            Raj Babbar            Samajwadi Party
# Ahmadnagar                             NaN                        NaN
# Ahmedabad                     Harin Pathak      Bharatiya Janta Party
# ...                                    ...                        ...
# West Delhi                             NaN                        NaN
# Yavatmal            Rathod Harising Nasaru      Bharatiya Janta Party
# Yavatmal-Washi                         NaN                        NaN
# Yavatmal-Washim                        NaN                        NaN
# Zahirabad                              NaN                        NaN
#
#                 Electors_2004 Votes_2004 Turnout_2004 Margin_2004  ...  \
# PC Name                                                            ...
# Adilabad            11,40,834   8,30,601       72.8 %      40,974  ...
# Adoor                9,60,122   6,82,227       71.1 %      54,534  ...
# Agra                14,30,713   6,42,675       44.9 %      57,342  ...
# Ahmadnagar                NaN        NaN          NaN         NaN  ...
# Ahmedabad           13,82,793   5,48,391       39.7 %      77,605  ...
# ...                       ...        ...          ...         ...  ...
# West Delhi                NaN        NaN          NaN         NaN  ...
# Yavatmal            11,33,605   6,63,001       58.5 %      56,804  ...
# Yavatmal-Washi            NaN        NaN          NaN         NaN  ...
# Yavatmal-Washim           NaN        NaN          NaN         NaN  ...
# Zahirabad                 NaN        NaN          NaN         NaN  ...
#
#                 No_2024  Type_2024                    State_2024  \
# PC Name
# Adilabad            1.0         ST                     Telangana
# Adoor               NaN        NaN                           NaN
# Agra               18.0         SC  Uttar Pradesh [2000 Onwards]
# Ahmadnagar         37.0        GEN                   Maharashtra
# Ahmedabad           NaN        NaN                           NaN
# ...                 ...        ...                           ...
# West Delhi          6.0        GEN          Delhi [1977 Onwards]
# Yavatmal            NaN        NaN                           NaN
# Yavatmal-Washi     14.0        GEN                   Maharashtra
# Yavatmal-Washim     NaN        NaN                           NaN
# Zahirabad           5.0        GEN                     Telangana
#
#                    Winning Candidate_2024  \
# PC Name
# Adilabad                     Godam Nagesh
# Adoor                                 NaN
# Agra                Prof S P Singh Baghel
# Ahmadnagar          Nilesh Dnyandev Lanke
# Ahmedabad                             NaN
# ...                                   ...
# West Delhi             Kamaljeet Sehrawat
# Yavatmal                              NaN
# Yavatmal-Washi   Sanjay Uttamrao Deshmukh
# Yavatmal-Washim                       NaN
# Zahirabad            Suresh Kumar Shetkar
#
#                                                        Party_2024  \
# PC Name
# Adilabad                                    Bharatiya Janta Party
# Adoor                                                         NaN
# Agra                                        Bharatiya Janta Party
# Ahmadnagar       Nationalist Congress Party – Sharadchandra Pawar
# Ahmedabad                                                     NaN
# ...                                                           ...
# West Delhi                                  Bharatiya Janta Party
# Yavatmal                                                      NaN
# Yavatmal-Washi              Shiv Sena (Uddhav Balasaheb Thackrey)
# Yavatmal-Washim                                               NaN
# Zahirabad                                Indian National Congress
#
#                 Electors_2024 Votes_2024  Turnout_2024  Margin_2024  \
# PC Name
# Adilabad            16,50,175  12,35,597        74.9 %       90,652
# Adoor                     NaN        NaN           NaN          NaN
# Agra                20,72,685  11,23,779        54.2 %     2,71,294
# Ahmadnagar          19,81,866  13,25,477        66.9 %       28,929
# Ahmedabad                 NaN        NaN           NaN          NaN
# ...                       ...        ...           ...          ...
# West Delhi          25,87,977  15,24,494        58.9 %     1,99,013
# Yavatmal                  NaN        NaN           NaN          NaN
# Yavatmal-Washi      19,40,916  12,25,530        63.1 %       94,473
# Yavatmal-Washim           NaN        NaN           NaN          NaN
# Zahirabad           16,41,410  12,36,593        75.3 %       46,188
#
#                 Margin %_2024
# PC Name
# Adilabad                 7.3%
# Adoor                     NaN
# Agra                    24.1%
# Ahmadnagar               2.2%
# Ahmedabad                 NaN
# ...                       ...
# West Delhi              13.1%
# Yavatmal                  NaN
# Yavatmal-Washi           7.7%
# Yavatmal-Washim           NaN
# Zahirabad                3.7%
#
# [825 rows x 55 columns]

# %%
import pandas as pd


def combine_rows(df, row1, row2, combined_row_name):
    row1_series = df.loc[row1]
    row2_series = df.loc[row2]
    combined_series = pd.Series(dtype=object, index=df.columns)
    for col in df.columns:
        value1 = row1_series[col]
        value2 = row2_series[col]
        if pd.notna(value1):
            combined_series[col] = value1
        elif pd.notna(value2):
            combined_series[col] = value2
        else:
            combined_series[col] = None

    combined_series.name = combined_row_name
    df = df.drop([row1, row2])
    df = pd.concat([df, combined_series.to_frame().T])
    return df


df = combine_rows(df, "Alleppey", "Alappuzha", "Allaphuza")

# %%
df.drop_duplicates(inplace=True)

# %%
df = combine_rows(df, "Gautam Buddh N", "Gautam Buddh Nagar", "Gautam Buddh Nagar")
df = combine_rows(df, "Jhalawar", "Jhalawar-Baran", "Jhalawar-Baran")
df = combine_rows(df, "Karauli-Dholpu", "Karauli-Dholpur", "Karauli-Dholpur")
df = combine_rows(df, "Ahmedabad", "Ahmedabad East", "Ahmedabad East")
df = combine_rows(df, "Gadchiroli-Chi", "Gadchiroli-Chimur", "Gadchiroli-Chimur")
df = combine_rows(df, "Ferozepur", "Ferozpur", "Ferozpur")
df = combine_rows(df, "Fatehpur", "Fatehpur Sikri", "Fatehpur Sikri")
df = combine_rows(df, "Fatehgarh Sahi", "Fatehgarh Sahib", "Fatehgarh Sahib")
df = combine_rows(df, "Domariaganj", "Domariyaganj", "Domariyaganj")
df = combine_rows(df, "Diamond Harbou", "Diamond Harbour", "Diamond Harbour")
df = combine_rows(df, "Dharwad", "Dharwad South", "Dharwad South")
df = combine_rows(df, "Davanagere", "Davangere", "Davangere")
df = combine_rows(df, "Dakshina Kanna", "Dakshina Kannada", "Dakshina Kannada")
df = combine_rows(df, "Daman And Diu", "Daman & Diu", "Daman & Diu")
df = combine_rows(
    df, "Dadra And Nagar Haveli", "Dadra & Nagar Haveli", "Dadra & Nagar Haveli"
)
df = combine_rows(df, "Chikkballapur", "Chikballapur", "Chikballapur")
df = combine_rows(df, "Burdwan - Durg", "Burdwan - Durgapur", "Burdwan - Durgapur")
df = combine_rows(df, "Burdwan", "Burdwan - Durgapur", "Burdwan - Durgapur")
df = combine_rows(df, "Bhiwani-Mahend", "Bhiwani-Mahendragarh", "Bhiwani-Mahendragarh")
df = combine_rows(df, "Bhandara - Gon", "Bhandara - Gondiya", "Bhandara - Gondiya")
df = combine_rows(df, "Bathinda", "Bhatinda", "Bhatinda")
df = combine_rows(df, "Bardhaman Purb", "Bardhaman Purba", "Bardhaman Purba")
df = combine_rows(df, "Bara Banki", "Barabanki", "Barabanki")
df = combine_rows(df, "Bangalore Cent", "Bangalore Central", "Bangalore Central")
df = combine_rows(df, "Bangalore Rura", "Bangalore Rural", "Bangalore Rural")
df = combine_rows(df, "Bangalore Nort", "Bangalore North", "Bangalore North")
df = combine_rows(df, "Bangalore Sout", "Bangalore South", "Bangalore South")
df = combine_rows(df, "Baharaich", "Bahraich", "Bahraich")
df = combine_rows(df, "Berhampore", "Baharampur", "Baharampur")
df = combine_rows(df, "Sonepat", "Sonipat", "Sonipat")
df = combine_rows(df, "Simla", "Shimla", "Shimla")
df = combine_rows(df, "Secunderabad", "Secundrabad", "Secundrabad")
df = combine_rows(df, "Sant Kabir Nag", "Sant Kabir Nagar", "Sant Kabir Nagar")
df = combine_rows(
    df, "Ratnagiri - Si", "Ratnagiri - Sindhudurg", "Ratnagiri - Sindhudurg"
)
df = combine_rows(df, "Ratnagiri", "Ratnagiri - Sindhudurg", "Ratnagiri - Sindhudurg")
df = combine_rows(df, "Pondicherry", "Puducherry", "Puducherry")
df = combine_rows(df, "Peddapalle", "Peddapalli", "Peddapalli")
df = combine_rows(df, "Palghar", "Palghat", "Palghat")
df = combine_rows(
    df, "Nainital-Udham", "Nainital-Udhamsingh Nagar", "Nainital-Udhamsingh Nagar"
)
df = combine_rows(
    df, "Nainital", "Nainital-Udhamsingh Nagar", "Nainital-Udhamsingh Nagar"
)
df = combine_rows(df, "Mayiladuturai", "Mayiladuthurai", "Mayiladuthurai")
df = combine_rows(df, "Mavelikara", "Mavelikkara", "Mavelikkara")
df = combine_rows(df, "Mandsaur", "Mandsour", "Mandsour")
df = combine_rows(df, "Maldaha Dakshi", "Maldaha Dakshin", "Maldaha Dakshin")
df = combine_rows(df, "Malda", "Maldaha Dakshin", "Maldaha Dakshin")
df = combine_rows(df, "Mahabubnagar", "Mahbubnagar", "Mahbubnagar")
df = combine_rows(df, "Krishnagar", "Krishnanagar", "Krishnanagar")
df = combine_rows(df, "Khed", "Kheda", "Kheda")
df = combine_rows(df, "Janjgir", "Janjgir-Champa", "Janjgir-Champa")
df = combine_rows(df, "Gautam Buddha Nagar", "Gautam Buddh Nagar", "Gautam Buddh Nagar")
df = combine_rows(df, "Yavatmal-Washi", "Yavatmal-Washim", "Yavatmal-Washim")
df = combine_rows(df, "Yavatmal", "Yavatmal-Washim", "Yavatmal-Washim")
df = combine_rows(df, "Udupi Chikmaga", "Udupi Chikmagalur", "Udupi Chikmagalur")
df = combine_rows(df, "Tonk-Sawai Mad", "Tonk-Sawai Madhopur", "Tonk-Sawai Madhopur")
df = combine_rows(df, "Tonk", "Tonk-Sawai Madhopur", "Tonk-Sawai Madhopur")
df = combine_rows(df, "Tiruchirappall", "Tiruchirappalli", "Tiruchirappalli")
df = combine_rows(df, "Thiruvananthap", "Thiruvananthapuram", "Thiruvananthapuram")
df = combine_rows(
    df,
    "Andaman & Nicobar Islands",
    "Andaman & Nicobar Islands",
    "Andaman & Nicobar Islands",
)
df = combine_rows(df, "Patna", "Patna Sahib", "Patna Sahib")

# %%
index_counts = df.index.value_counts()
duplicate_indices = index_counts[index_counts > 1].index
print(duplicate_indices)
# Out:
# Index(['Aurangabad', 'Hamirpur', 'Maharajganj'], dtype='object')

# %%
filtered_rows = []
for idx in duplicate_indices.unique():
    rows = df.loc[idx]
    if isinstance(rows, pd.DataFrame):
        filtered_rows.append(rows.iloc[0])  # First occurrence
        filtered_rows.append(rows.iloc[-1])  # Last occurrence
    else:
        filtered_rows.append(rows)
filtered_df = pd.DataFrame(filtered_rows)
filtered_df
# Out:
#              idx_2004  No_2004 Type_2004                    State_2004  \
# Aurangabad       36.0     37.0       GEN          Bihar [2000 Onwards]
# Aurangabad       37.0     33.0       GEN                   Maharashtra
# Hamirpur        207.0     56.0        SC  Uttar Pradesh [2000 Onwards]
# Hamirpur        208.0      4.0        SC              Himachal Pradesh
# Maharajganj     324.0      6.0       GEN          Bihar [2000 Onwards]
# Maharajganj     325.0     35.0       GEN  Uttar Pradesh [2000 Onwards]
#
#                     Winning Candidate_2004                Party_2004  \
# Aurangabad                    Nikhil Kumar  Indian National Congress
# Aurangabad              Chandrakant Khaire                 Shiv Sena
# Hamirpur     Rajnarayan Alias Rajju Mahraj           Samajwadi Party
# Hamirpur                    Suresh Chandel     Bharatiya Janta Party
# Maharajganj               Prabhunath Singh       Janata Dal (United)
# Maharajganj               Pankaj Choudhary     Bharatiya Janta Party
#
#             Electors_2004 Votes_2004 Turnout_2004 Margin_2004  ... No_2024  \
# Aurangabad      14,01,973   7,67,159       54.7 %       7,460  ...    19.0
# Aurangabad      16,36,117   9,11,532       55.7 %    1,21,923  ...    37.0
# Hamirpur        11,85,235   6,04,055       51.0 %      37,154  ...    47.0
# Hamirpur        10,64,238   6,49,994       61.1 %       1,615  ...     3.0
# Maharajganj     11,14,665   6,64,381       59.6 %      46,465  ...    63.0
# Maharajganj     13,11,205   7,46,614       56.9 %      64,799  ...    19.0
#
#              Type_2024                    State_2024  \
# Aurangabad         GEN                   Maharashtra
# Aurangabad         GEN          Bihar [2000 Onwards]
# Hamirpur           GEN  Uttar Pradesh [2000 Onwards]
# Hamirpur           GEN              Himachal Pradesh
# Maharajganj        GEN  Uttar Pradesh [2000 Onwards]
# Maharajganj        GEN          Bihar [2000 Onwards]
#
#                  Winning Candidate_2024             Party_2024 Electors_2024  \
# Aurangabad   Bhumare Sandipanrao Asaram              Shiv Sena     20,59,710
# Aurangabad            Abhay Kumar Sinha   Rashtriya Janata Dal     18,71,564
# Hamirpur            Ajendra Singh Lodhi        Samajwadi Party     18,39,761
# Hamirpur            Anurag Singh Thakur  Bharatiya Janta Party     14,32,636
# Maharajganj            Pankaj Chaudhary  Bharatiya Janta Party     20,04,050
# Maharajganj   Janardan Singh "sigriwal"  Bharatiya Janta Party     19,34,937
#
#             Votes_2024  Turnout_2024  Margin_2024 Margin %_2024
# Aurangabad   13,02,197        63.2 %     1,34,650         10.3%
# Aurangabad    9,45,880        50.5 %       79,111          8.4%
# Hamirpur     11,15,299        60.6 %        2,629          0.2%
# Hamirpur     10,47,263        73.1 %     1,82,357         17.4%
# Maharajganj  12,10,451        60.4 %       35,451          2.9%
# Maharajganj  10,14,109        52.4 %     1,02,651         10.1%
#
# [6 rows x 55 columns]

# %%
df = df[~df.index.isin(duplicate_indices.unique())]
df = pd.concat([df, filtered_df])
df
# Out:
#                idx_2004 No_2004 Type_2004                    State_2004  \
# Adilabad            1.0    35.0       GEN                Andhra Pradesh
# Adoor               2.0    17.0       GEN                        Kerala
# Agra                3.0    69.0       GEN  Uttar Pradesh [2000 Onwards]
# Ahmadnagar          NaN     NaN       NaN                           NaN
# Ahmedabad West      NaN     NaN       NaN                           NaN
# ...                 ...     ...       ...                           ...
# Aurangabad         37.0    33.0       GEN                   Maharashtra
# Hamirpur          207.0    56.0        SC  Uttar Pradesh [2000 Onwards]
# Hamirpur          208.0     4.0        SC              Himachal Pradesh
# Maharajganj       324.0     6.0       GEN          Bihar [2000 Onwards]
# Maharajganj       325.0    35.0       GEN  Uttar Pradesh [2000 Onwards]
#
#                        Winning Candidate_2004                 Party_2004  \
# Adilabad            Madhusudhan Reddy Takkala  Telangana Rashtra Samithi
# Adoor                      Chengara Surendran   Communist Party Of India
# Agra                               Raj Babbar            Samajwadi Party
# Ahmadnagar                                NaN                        NaN
# Ahmedabad West                            NaN                        NaN
# ...                                       ...                        ...
# Aurangabad                 Chandrakant Khaire                  Shiv Sena
# Hamirpur        Rajnarayan Alias Rajju Mahraj            Samajwadi Party
# Hamirpur                       Suresh Chandel      Bharatiya Janta Party
# Maharajganj                  Prabhunath Singh        Janata Dal (United)
# Maharajganj                  Pankaj Choudhary      Bharatiya Janta Party
#
#                Electors_2004 Votes_2004 Turnout_2004 Margin_2004  ... No_2024  \
# Adilabad           11,40,834   8,30,601       72.8 %      40,974  ...     1.0
# Adoor               9,60,122   6,82,227       71.1 %      54,534  ...     NaN
# Agra               14,30,713   6,42,675       44.9 %      57,342  ...    18.0
# Ahmadnagar               NaN        NaN          NaN         NaN  ...    37.0
# Ahmedabad West           NaN        NaN          NaN         NaN  ...     8.0
# ...                      ...        ...          ...         ...  ...     ...
# Aurangabad         16,36,117   9,11,532       55.7 %    1,21,923  ...    37.0
# Hamirpur           11,85,235   6,04,055       51.0 %      37,154  ...    47.0
# Hamirpur           10,64,238   6,49,994       61.1 %       1,615  ...     3.0
# Maharajganj        11,14,665   6,64,381       59.6 %      46,465  ...    63.0
# Maharajganj        13,11,205   7,46,614       56.9 %      64,799  ...    19.0
#
#                Type_2024                    State_2024  \
# Adilabad              ST                     Telangana
# Adoor                NaN                           NaN
# Agra                  SC  Uttar Pradesh [2000 Onwards]
# Ahmadnagar           GEN                   Maharashtra
# Ahmedabad West        SC                       Gujarat
# ...                  ...                           ...
# Aurangabad           GEN          Bihar [2000 Onwards]
# Hamirpur             GEN  Uttar Pradesh [2000 Onwards]
# Hamirpur             GEN              Himachal Pradesh
# Maharajganj          GEN  Uttar Pradesh [2000 Onwards]
# Maharajganj          GEN          Bihar [2000 Onwards]
#
#                        Winning Candidate_2024  \
# Adilabad                         Godam Nagesh
# Adoor                                     NaN
# Agra                    Prof S P Singh Baghel
# Ahmadnagar              Nilesh Dnyandev Lanke
# Ahmedabad West  Dineshbhai Makwana (ADVOCATE)
# ...                                       ...
# Aurangabad                  Abhay Kumar Sinha
# Hamirpur                  Ajendra Singh Lodhi
# Hamirpur                  Anurag Singh Thakur
# Maharajganj                  Pankaj Chaudhary
# Maharajganj         Janardan Singh "sigriwal"
#
#                                                       Party_2024  \
# Adilabad                                   Bharatiya Janta Party
# Adoor                                                        NaN
# Agra                                       Bharatiya Janta Party
# Ahmadnagar      Nationalist Congress Party – Sharadchandra Pawar
# Ahmedabad West                             Bharatiya Janta Party
# ...                                                          ...
# Aurangabad                                  Rashtriya Janata Dal
# Hamirpur                                         Samajwadi Party
# Hamirpur                                   Bharatiya Janta Party
# Maharajganj                                Bharatiya Janta Party
# Maharajganj                                Bharatiya Janta Party
#
#                Electors_2024 Votes_2024 Turnout_2024 Margin_2024 Margin %_2024
# Adilabad           16,50,175  12,35,597       74.9 %      90,652          7.3%
# Adoor                    NaN        NaN          NaN         NaN           NaN
# Agra               20,72,685  11,23,779       54.2 %    2,71,294         24.1%
# Ahmadnagar         19,81,866  13,25,477       66.9 %      28,929          2.2%
# Ahmedabad West     17,26,987   9,66,646       56.0 %    2,86,437         29.6%
# ...                      ...        ...          ...         ...           ...
# Aurangabad         18,71,564   9,45,880       50.5 %      79,111          8.4%
# Hamirpur           18,39,761  11,15,299       60.6 %       2,629          0.2%
# Hamirpur           14,32,636  10,47,263       73.1 %    1,82,357         17.4%
# Maharajganj        20,04,050  12,10,451       60.4 %      35,451          2.9%
# Maharajganj        19,34,937  10,14,109       52.4 %    1,02,651         10.1%
#
# [676 rows x 55 columns]

# %%
df.to_csv("all.csv")
df.isna().sum()
# Out:
# idx_2004                  133
# No_2004                   133
# Type_2004                 133
# State_2004                133
# Winning Candidate_2004    133
# Party_2004                133
# Electors_2004             133
# Votes_2004                133
# Turnout_2004              133
# Margin_2004               133
# Margin %_2004             133
# idx_2009                  134
# No_2009                   134
# Type_2009                 134
# State_2009                134
# Winning Candidate_2009    134
# Party_2009                134
# Electors_2009             134
# Votes_2009                134
# Turnout_2009              134
# Margin_2009               134
# Margin %_2009             134
# idx                       134
# No                        134
# Type                      134
# State                     134
# Winning Candidate         134
# Party                     134
# Electors                  134
# Votes                     134
# Turnout                   134
# Margin                    134
# Margin %                  134
# idx_2019                  136
# No_2019                   136
# Type_2019                 168
# State_2019                136
# Winning Candidate_2019    136
# Party_2019                136
# Electors_2019             136
# Votes_2019                136
# Turnout_2019              136
# Margin_2019               136
# Margin %_2019             136
# idx_2024                  134
# No_2024                   134
# Type_2024                 160
# State_2024                134
# Winning Candidate_2024    134
# Party_2024                134
# Electors_2024             134
# Votes_2024                134
# Turnout_2024              135
# Margin_2024               135
# Margin %_2024             135
# dtype: int64

# %%
df = pd.read_csv("all.csv", index_col=0)
rows_with_nulls = df[df.isna().any(axis=1)]
rows_with_nulls
# Out:
#                            idx_2004  No_2004 Type_2004  \
# Adoor                           2.0     17.0       GEN
# Ahmadnagar                      NaN      NaN       NaN
# Ahmedabad West                  NaN      NaN       NaN
# Ahmednagar                      5.0     39.0       GEN
# Alathur                         NaN      NaN       NaN
# ...                             ...      ...       ...
# Sant Kabir Nagar                NaN      NaN       NaN
# Gautam Buddh Nagar              NaN      NaN       NaN
# Udupi Chikmagalur               NaN      NaN       NaN
# Thiruvananthapuram              NaN      NaN       NaN
# Andaman & Nicobar Islands      26.0      1.0       GEN
#
#                                           State_2004  \
# Adoor                                         Kerala
# Ahmadnagar                                       NaN
# Ahmedabad West                                   NaN
# Ahmednagar                               Maharashtra
# Alathur                                          NaN
# ...                                              ...
# Sant Kabir Nagar                                 NaN
# Gautam Buddh Nagar                               NaN
# Udupi Chikmagalur                                NaN
# Thiruvananthapuram                               NaN
# Andaman & Nicobar Islands  Andaman & Nicobar Islands
#
#                              Winning Candidate_2004  \
# Adoor                            Chengara Surendran
# Ahmadnagar                                      NaN
# Ahmedabad West                                  NaN
# Ahmednagar                 Gadakh Tukaram Gangadhar
# Alathur                                         NaN
# ...                                             ...
# Sant Kabir Nagar                                NaN
# Gautam Buddh Nagar                              NaN
# Udupi Chikmagalur                               NaN
# Thiruvananthapuram                              NaN
# Andaman & Nicobar Islands         Manoranjan Bhakta
#
#                                            Party_2004 Electors_2004  \
# Adoor                        Communist Party Of India      9,60,122
# Ahmadnagar                                        NaN           NaN
# Ahmedabad West                                    NaN           NaN
# Ahmednagar                 Nationalist Congress Party     12,95,593
# Alathur                                           NaN           NaN
# ...                                               ...           ...
# Sant Kabir Nagar                                  NaN           NaN
# Gautam Buddh Nagar                                NaN           NaN
# Udupi Chikmagalur                                 NaN           NaN
# Thiruvananthapuram                                NaN           NaN
# Andaman & Nicobar Islands    Indian National Congress      2,41,645
#
#                           Votes_2004 Turnout_2004 Margin_2004  ... No_2024  \
# Adoor                       6,82,227       71.1 %      54,534  ...     NaN
# Ahmadnagar                       NaN          NaN         NaN  ...    37.0
# Ahmedabad West                   NaN          NaN         NaN  ...     8.0
# Ahmednagar                  6,86,554       53.0 %      75,077  ...     NaN
# Alathur                          NaN          NaN         NaN  ...     9.0
# ...                              ...          ...         ...  ...     ...
# Sant Kabir Nagar                 NaN          NaN         NaN  ...    62.0
# Gautam Buddh Nagar               NaN          NaN         NaN  ...    13.0
# Udupi Chikmagalur                NaN          NaN         NaN  ...    15.0
# Thiruvananthapuram               NaN          NaN         NaN  ...    20.0
# Andaman & Nicobar Islands   1,53,804       63.7 %      30,500  ...     NaN
#
#                            Type_2024                    State_2024  \
# Adoor                            NaN                           NaN
# Ahmadnagar                       GEN                   Maharashtra
# Ahmedabad West                    SC                       Gujarat
# Ahmednagar                       NaN                           NaN
# Alathur                           SC                        Kerala
# ...                              ...                           ...
# Sant Kabir Nagar                 GEN  Uttar Pradesh [2000 Onwards]
# Gautam Buddh Nagar               GEN  Uttar Pradesh [2000 Onwards]
# Udupi Chikmagalur                GEN                     Karnataka
# Thiruvananthapuram               GEN                        Kerala
# Andaman & Nicobar Islands        NaN                           NaN
#
#                                   Winning Candidate_2024  \
# Adoor                                                NaN
# Ahmadnagar                         Nilesh Dnyandev Lanke
# Ahmedabad West             Dineshbhai Makwana (ADVOCATE)
# Ahmednagar                                           NaN
# Alathur                                  K.Radhakrishnan
# ...                                                  ...
# Sant Kabir Nagar                  Laxmikant Pappu Nishad
# Gautam Buddh Nagar                     Dr. Mahesh Sharma
# Udupi Chikmagalur                  Kota Srinivas Poojary
# Thiruvananthapuram                        Shashi Tharoor
# Andaman & Nicobar Islands                            NaN
#
#                                                                  Party_2024  \
# Adoor                                                                   NaN
# Ahmadnagar                 Nationalist Congress Party – Sharadchandra Pawar
# Ahmedabad West                                        Bharatiya Janta Party
# Ahmednagar                                                              NaN
# Alathur                                  Communist Party Of India (Marxist)
# ...                                                                     ...
# Sant Kabir Nagar                                            Samajwadi Party
# Gautam Buddh Nagar                                    Bharatiya Janta Party
# Udupi Chikmagalur                                     Bharatiya Janta Party
# Thiruvananthapuram                                 Indian National Congress
# Andaman & Nicobar Islands                                               NaN
#
#                           Electors_2024 Votes_2024  Turnout_2024  Margin_2024  \
# Adoor                               NaN        NaN           NaN          NaN
# Ahmadnagar                    19,81,866  13,25,477        66.9 %       28,929
# Ahmedabad West                17,26,987   9,66,646        56.0 %     2,86,437
# Ahmednagar                          NaN        NaN           NaN          NaN
# Alathur                       13,37,496   9,92,268        74.2 %       20,111
# ...                                 ...        ...           ...          ...
# Sant Kabir Nagar              20,71,964  10,91,202        52.7 %       92,170
# Gautam Buddh Nagar            26,75,148  14,37,244        53.7 %     5,59,472
# Udupi Chikmagalur             15,85,162  12,29,418        77.6 %     2,59,175
# Thiruvananthapuram            14,30,531   9,62,983        67.3 %       16,077
# Andaman & Nicobar Islands           NaN        NaN           NaN          NaN
#
#                           Margin %_2024
# Adoor                               NaN
# Ahmadnagar                         2.2%
# Ahmedabad West                    29.6%
# Ahmednagar                          NaN
# Alathur                            2.0%
# ...                                 ...
# Sant Kabir Nagar                   8.4%
# Gautam Buddh Nagar                38.9%
# Udupi Chikmagalur                 21.1%
# Thiruvananthapuram                 1.7%
# Andaman & Nicobar Islands           NaN
#
# [295 rows x 55 columns]

# %%
def convert_to_float(column):
    column = column.astype(str)
    try:
        column = column.str.replace("%", "").str.replace(",", "").astype(float)
    except:
        print(column)
    return column

# %%
v = df.filter(regex="Electors|Votes|Turnout|Margin").columns
for column in v:
    df[column] = convert_to_float(df[column])
# Out:
# Adilabad          12,35,597
# Adoor                   nan
# Agra              11,23,779
# Ahmadnagar        13,25,477
# Ahmedabad West     9,66,646
#                     ...
# Aurangabad         9,45,880
# Hamirpur          11,15,299
# Hamirpur          10,47,263
# Maharajganj       12,10,451
# Maharajganj       10,14,109
# Name: Votes_2024, Length: 676, dtype: object

# %%
df.dropna(inplace=True)
df.to_csv("all.csv", index=True)

# %%
to_drop = df.filter(regex="No|idx|Type|Winning").columns
df.drop(to_drop, axis=1, inplace=True)
df
# Out:
#                                State_2004                 Party_2004  \
# Adilabad                   Andhra Pradesh  Telangana Rashtra Samithi
# Agra         Uttar Pradesh [2000 Onwards]            Samajwadi Party
# Ajmer                           Rajasthan      Bharatiya Janta Party
# Akbarpur     Uttar Pradesh [2000 Onwards]        Bahujan Samaj Party
# Akola                         Maharashtra      Bharatiya Janta Party
# ...                                   ...                        ...
# Aurangabad                    Maharashtra                  Shiv Sena
# Hamirpur     Uttar Pradesh [2000 Onwards]            Samajwadi Party
# Hamirpur                 Himachal Pradesh      Bharatiya Janta Party
# Maharajganj          Bihar [2000 Onwards]        Janata Dal (United)
# Maharajganj  Uttar Pradesh [2000 Onwards]      Bharatiya Janta Party
#
#              Electors_2004  Votes_2004  Turnout_2004  Margin_2004  \
# Adilabad         1140834.0    830601.0          72.8      40974.0
# Agra             1430713.0    642675.0          44.9      57342.0
# Ajmer            1203803.0    529138.0          44.0     127976.0
# Akbarpur         1446088.0    741543.0          51.3      58269.0
# Akola            1271055.0    734524.0          57.8     106371.0
# ...                    ...         ...           ...          ...
# Aurangabad       1636117.0    911532.0          55.7     121923.0
# Hamirpur         1185235.0    604055.0          51.0      37154.0
# Hamirpur         1064238.0    649994.0          61.1       1615.0
# Maharajganj      1114665.0    664381.0          59.6      46465.0
# Maharajganj      1311205.0    746614.0          56.9      64799.0
#
#              Margin %_2004                    State_2009  \
# Adilabad               4.9                Andhra Pradesh
# Agra                   8.9  Uttar Pradesh [2000 Onwards]
# Ajmer                 24.2                     Rajasthan
# Akbarpur               7.9  Uttar Pradesh [2000 Onwards]
# Akola                 14.5                   Maharashtra
# ...                    ...                           ...
# Aurangabad            13.4                   Maharashtra
# Hamirpur               6.2              Himachal Pradesh
# Hamirpur               0.2  Uttar Pradesh [2000 Onwards]
# Maharajganj            7.0          Bihar [2000 Onwards]
# Maharajganj            8.7  Uttar Pradesh [2000 Onwards]
#
#                            Party_2009  Electors_2009  ...  Turnout_2019  \
# Adilabad                 Telugu Desam      1131211.0  ...          77.9
# Agra            Bharatiya Janta Party      1539683.0  ...          61.7
# Ajmer        Indian National Congress      1455339.0  ...          69.0
# Akbarpur     Indian National Congress      1461050.0  ...          60.3
# Akola           Bharatiya Janta Party      1480606.0  ...          64.2
# ...                               ...            ...  ...           ...
# Aurangabad                  Shiv Sena      1417964.0  ...          55.5
# Hamirpur        Bharatiya Janta Party      1187377.0  ...          64.4
# Hamirpur          Bahujan Samaj Party      1498840.0  ...          79.9
# Maharajganj      Rashtriya Janata Dal      1312219.0  ...          55.5
# Maharajganj  Indian National Congress      1509167.0  ...          66.3
#
#              Margin_2019  Margin %_2019                    State_2024  \
# Adilabad         58560.0            5.5                     Telangana
# Agra            211546.0           18.5  Uttar Pradesh [2000 Onwards]
# Ajmer           416424.0           33.0                     Rajasthan
# Akbarpur        275142.0           26.8  Uttar Pradesh [2000 Onwards]
# Akola           275596.0           24.6                   Maharashtra
# ...                  ...            ...                           ...
# Aurangabad       72607.0            7.7          Bihar [2000 Onwards]
# Hamirpur        248652.0           22.8  Uttar Pradesh [2000 Onwards]
# Hamirpur        399572.0           40.4              Himachal Pradesh
# Maharajganj     230772.0           23.7  Uttar Pradesh [2000 Onwards]
# Maharajganj     340424.0           27.7          Bihar [2000 Onwards]
#
#                         Party_2024 Electors_2024  Votes_2024  Turnout_2024  \
# Adilabad     Bharatiya Janta Party     1650175.0   12,35,597          74.9
# Agra         Bharatiya Janta Party     2072685.0   11,23,779          54.2
# Ajmer        Bharatiya Janta Party     1995699.0   12,01,179          60.2
# Akbarpur     Bharatiya Janta Party     1869167.0   10,86,953          58.2
# Akola        Bharatiya Janta Party     1890814.0   11,73,072          62.0
# ...                            ...           ...         ...           ...
# Aurangabad    Rashtriya Janata Dal     1871564.0    9,45,880          50.5
# Hamirpur           Samajwadi Party     1839761.0   11,15,299          60.6
# Hamirpur     Bharatiya Janta Party     1432636.0   10,47,263          73.1
# Maharajganj  Bharatiya Janta Party     2004050.0   12,10,451          60.4
# Maharajganj  Bharatiya Janta Party     1934937.0   10,14,109          52.4
#
#              Margin_2024  Margin %_2024
# Adilabad         90652.0            7.3
# Agra            271294.0           24.1
# Ajmer           329991.0           27.5
# Akbarpur         44345.0            4.1
# Akola            40626.0            3.5
# ...                  ...            ...
# Aurangabad       79111.0            8.4
# Hamirpur          2629.0            0.2
# Hamirpur        182357.0           17.4
# Maharajganj      35451.0            2.9
# Maharajganj     102651.0           10.1
#
# [381 rows x 35 columns]

# %%
import json

states = df.filter(regex="State").columns
states = df.melt(value_vars=states)["value"].unique()
states = {j: i for i, j in enumerate(states)}
df.replace(states, inplace=True)
json.dump(states, open("states.json", "w"))
df
# Out:
# /tmp/ipykernel_13593/3691371030.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(states, inplace=True)

# %%
parties = df.filter(regex="Party").columns
parties = df.melt(value_vars=parties)["value"].unique()
parties = {j: i for i, j in enumerate(parties)}
df.replace(parties, inplace=True)
json.dump(parties, open("parties.json", "w"))
df
# Out:
# /tmp/ipykernel_13593/856309152.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(parties, inplace=True)

# %%
df.to_csv("cleaned.csv", index=True)
