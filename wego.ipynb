# %%
import pandas as pandas
import os

l = [i for i in os.listdir(".") if i.endswith(".csv")]
df = pandas.concat([pandas.read_csv(i) for i in l])
df
# Out:
#              PC Name    No Type                         State  \
# 0           Adilabad   1.0   ST                Andhra Pradesh
# 1               Agra  18.0   SC  Uttar Pradesh [2000 Onwards]
# 2         Ahmadnagar  37.0  GEN                   Maharashtra
# 3     Ahmedabad East   7.0  GEN                       Gujarat
# 4     Ahmedabad West   8.0   SC                       Gujarat
# ..               ...   ...  ...                           ...
# 538           Wardha   8.0  GEN                   Maharashtra
# 539          Wayanad   4.0  GEN                        Kerala
# 540       West Delhi   6.0  GEN          Delhi [1977 Onwards]
# 541  Yavatmal-Washim  14.0  GEN                   Maharashtra
# 542        Zahirabad   5.0  GEN                     Telangana
#
#                      Winning Candidate                      Party Electors  \
# 0                        Rathod Ramesh               Telugu Desam  1131211
# ...
