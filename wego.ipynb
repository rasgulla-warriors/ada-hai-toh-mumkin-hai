# %%
import pandas as pd
import os

l = [i for i in os.listdir(".") if i.endswith(".csv")]
df = pd.concat([pd.read_csv(i) for i in l])
df
# Out:
#      idx         PC Name  No Type                         State  \
# 0      1        Adilabad   1   ST                Andhra Pradesh
# 1      2            Agra  18   SC  Uttar Pradesh [2000 Onwards]
# 2      3      Ahmadnagar  37  GEN                   Maharashtra
# 3      4  Ahmedabad East   7  GEN                       Gujarat
# 4      5  Ahmedabad West   8   SC                       Gujarat
# ..   ...             ...  ..  ...                           ...
# 538  539       Vishnupur  36  GEN                   West Bengal
# 539  540        Warangal  39  GEN                Andhra Pradesh
# 540  541          Wardha  27  GEN                   Maharashtra
# 541  542          Washim  20   ST                   Maharashtra
# 542  543        Yavatmal  28  GEN                   Maharashtra
#
#                           Winning Candidate  \
# 0                             Rathod Ramesh
# 1                            Dr. Ramshankar
# 2              Gandhi Dilipkumar Mansukhlal
# ...

# %%
df.index = range(len(df))
# Out:
#       idx         PC Name  No Type                         State  \
# 0       1        Adilabad   1   ST                Andhra Pradesh
# 1       2            Agra  18   SC  Uttar Pradesh [2000 Onwards]
# 2       3      Ahmadnagar  37  GEN                   Maharashtra
# 3       4  Ahmedabad East   7  GEN                       Gujarat
# 4       5  Ahmedabad West   8   SC                       Gujarat
# ...   ...             ...  ..  ...                           ...
# 2708  539       Vishnupur  36  GEN                   West Bengal
# 2709  540        Warangal  39  GEN                Andhra Pradesh
# 2710  541          Wardha  27  GEN                   Maharashtra
# 2711  542          Washim  20   ST                   Maharashtra
# 2712  543        Yavatmal  28  GEN                   Maharashtra
#
#                            Winning Candidate  \
# 0                              Rathod Ramesh
# 1                             Dr. Ramshankar
# 2               Gandhi Dilipkumar Mansukhlal
# ...
